# %% [markdown]
# <a href="https://colab.research.google.com/github/AbnerNeves/Colab/blob/master/Covid_AM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
covid = pd.read_csv("Covid_AM.csv", sep =';')

# %%
covid.tail()
# Out:
#    regiao estado        data  ...    ln(casos)   ln(obitos)  ln(recuperados)
# 81  Norte     AM  05/06/2020  ...  10,77199461  7,696212639      10,55349234
# 82  Norte     AM  06/06/2020  ...  10,79519867  7,711101252      10,57719704
# 83  Norte     AM  07/06/2020  ...  10,80507066  7,719129841      10,58625606
# 84  Norte     AM  08/06/2020  ...  10,81613164   7,72841578      10,59658473
# 85  Norte     AM  09/06/2020  ...  10,84417817  7,747596839      10,62716394
#
# [5 rows x 12 columns]

# %%
covid.describe()
# Out:
#        casos_acumulados  obitos_acumados  ...  casos_novos  obitos_novos
# count         86.000000        86.000000  ...    86.000000     86.000000
# mean       12539.953488       729.476744  ...   595.732558     26.918605
# std        15955.504157       808.570907  ...   687.354236     26.118830
# min            1.000000         0.000000  ...     0.000000      0.000000
# 25%          445.750000        15.250000  ...    69.000000      3.250000
# 50%         3880.500000       312.000000  ...   329.500000     19.500000
# 75%        20766.750000      1428.000000  ...  1130.250000     44.000000
# max        51234.000000      2315.000000  ...  2763.000000    102.000000
#
# [8 rows x 6 columns]

# %%
covid.corr().round(3)
# Out:
#                   casos_acumulados  obitos_acumados  ...  casos_novos  obitos_novos
# casos_acumulados             1.000            0.978  ...        0.757         0.454
# obitos_acumados              0.978            1.000  ...        0.818         0.585
# recuperados                  0.993            0.954  ...        0.723         0.377
# casos_ativos                 0.848            0.904  ...        0.760         0.710
# casos_novos                  0.757            0.818  ...        1.000         0.758
# obitos_novos                 0.454            0.585  ...        0.758         1.000
#
# [6 rows x 6 columns]

# %%
ax = sns.pairplot(data = covid)

# %%
#ax = sns.relplot(y='recuperados',x=covid.index, kind='line', data = covid)
#ax.figure.set_size_inches(20,10)
#ax.set_ylabel("Frequencia")
#ax.shade = True

# %%
ax = sns.distplot(covid["obitos_acumulados"].values, hist_kws = {'cumulative':True}, kde_kws = {'cumulative':True})
ax.figure.set_size_inches(20,10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'obitos_acumulados'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-5d4ca8a8ef61> in <module>()
# ...

# %%
g = sns.relplot(x="data", y='casos_acumulados', kind = 'line', data = covid)
